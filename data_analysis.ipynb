# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("D:/internship_clg_aiml/report-cs.xlsx")

# %%
df
# Out:
#            Category  Ticket Id         Due by Time            Group  Impact  \
# 0       CS-Vuln Mgt      37383 2025-04-03 14:00:00  InfraSec Celito  Medium
# 1     IS-Monitoring      37384 2025-04-11 08:00:12  InfraSec Celito     Low
# 2     IS-Monitoring      37385 2025-04-11 08:00:34  InfraSec Celito     Low
# 3           CS-SIEM      37386 2025-04-03 14:00:00  InfraSec Celito  Medium
# 4      CS-Email Sec      37389 2025-04-11 08:00:00  InfraSec Celito     Low
# ...             ...        ...                 ...              ...     ...
# 1197        CS-SIEM      39218 2025-07-10 17:00:00  InfraSec Celito     Low
# 1198  IS-Monitoring      39221 2025-07-11 09:42:36  InfraSec Celito     Low
# 1199  IS-Monitoring      39222 2025-07-11 12:50:00  InfraSec Celito     Low
# 1200  IS-Monitoring      39223 2025-07-11 13:25:45  InfraSec Celito     Low
# 1201  IS-Monitoring      39224 2025-07-11 15:11:00  InfraSec Celito     Low
#
#                Item Priority               Requester Email         Agent  \
# 0            Report   Medium     msanmiguel@celitotech.com  Akshay Velma
# 1            Report      Low     msanmiguel@celitotech.com  Akshay Velma
# 2            Report      Low     msanmiguel@celitotech.com  Akshay Velma
# 3            Benign   Medium    insight_noreply@rapid7.com  Akshay Velma
# 4            Benign      Low  mdr_notifications@rapid7.com  Akshay Velma
# ...             ...      ...                           ...           ...
# 1197         Benign      Low    insight_noreply@rapid7.com      No Agent
# 1198         Benign      Low    insight_noreply@rapid7.com  Akshay Velma
# 1199         Benign      Low   azure-noreply@microsoft.com  Akshay Velma
# 1200  True Positive      Low    kdaryabeygi@celitotech.com  Akshay Velma
# 1201         Report      Low    do-not-reply@jumpcloud.com  Akshay Velma
#
#       Status    Sub-Category  \
# 0     Closed  Scheduled Task
# 1     Closed  Scheduled Task
# 2     Closed  Scheduled Task
# 3     Closed        Incident
# 4     Closed        Incident
# ...      ...             ...
# 1197    Open             NaN
# 1198    Open             NaN
# 1199  Closed        Incident
# 1200    Open             NaN
# 1201  Closed        Incident
#
#                                                 Subject             Type  \
# 0                              Vulnerability Management  Service Request
# 1                               Email Forwarding Report  Service Request
# 2                                    Awareness Training  Service Request
# 3     New InsightIDR Investigation - Account nelson....         Incident
# 4     MDR Notification: Authentication Activity - Ce...         Incident
# ...                                                 ...              ...
# 1197  New InsightIDR Investigation - Helyx Data: Fai...         Incident
# 1198          Authorized user removed from your account         Incident
# 1199  Resolved:Sev3 Azure Monitor Alert Available Me...         Incident
# 1200  [Phish Alert] Celito Tech and Whiteswan Identi...         Incident
# 1201  JumpCloud Incident - Degraded System Insights ...         Incident
#
#                                             Close Notes         Closed Time  \
# 0     Report has been reviewed and remediation proje... 2025-05-13 06:50:01
# 1               Report has been generated and reviewed  2025-04-03 10:04:13
# 2              Awareness campaign is currently running  2025-04-29 08:08:17
# 3     Nothing suspicious found. Detailed investigati... 2025-04-02 05:30:19
# 4     Nothing suspicious found. Detailed investigati... 2025-04-02 05:32:26
# ...                                                 ...                 ...
# 1197                                                NaN                 NaT
# 1198                                                NaN                 NaT
# 1199  The memory usage on the virtual machine improv... 2025-07-02 07:53:22
# 1200                                                NaN                 NaT
# 1201              Jumpcloud is not being used in Jasper 2025-07-03 06:36:42
#
#             Created Time                           Department  \
# 0    2025-04-01 06:00:54  IT Infrastructure and Cybersecurity
# 1    2025-04-01 06:01:00  IT Infrastructure and Cybersecurity
# 2    2025-04-01 06:01:05  IT Infrastructure and Cybersecurity
# 3    2025-04-01 06:40:49  IT Infrastructure and Cybersecurity
# 4    2025-04-01 07:32:37  IT Infrastructure and Cybersecurity
# ...                  ...                                  ...
# 1197 2025-06-30 07:24:44                                  NaN
# 1198 2025-06-30 09:42:35                                  NaN
# 1199 2025-06-30 12:49:38  IT Infrastructure and Cybersecurity
# 1200 2025-06-30 13:25:44                                  NaN
# 1201 2025-06-30 15:10:46  IT Infrastructure and Cybersecurity
#
#                                             Description
# 0             Run reports, meet with team to prioritize
# 1                    Produce an email forwarding report
# 2     Review user list Review content to be sent Gen...
# 3     New InsightIDR investigation Account nelson.da...
# 4     This Message originated outside your organizat...
# ...                                                 ...
# 1197  New InsightIDR investigation Helyx Data: Faile...
# 1198   Basic Email Template This Message originated ...
# 1199  This Message originated outside your organizat...
# 1200  This Message originated outside your organizat...
# 1201  This Message originated outside your organizat...
#
# [1202 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Category             0
# Ticket Id            0
# Due by Time          0
# Group                0
# Impact               0
# Item                 0
# Priority             0
# Requester Email      0
# Agent                0
# Status               0
# Sub-Category       497
# Subject              0
# Type                 0
# Close Notes        556
# Closed Time         29
# Created Time         0
# Department         501
# Description          4
# dtype: int64

# %%
df.columns
# Out:
# Index(['Category', 'Ticket Id', 'Due by Time', 'Group', 'Impact', 'Item',
#        'Priority', 'Requester Email', 'Agent', 'Status', 'Sub-Category',
#        'Subject', 'Type', 'Close Notes', 'Closed Time', 'Created Time',
#        'Department', 'Description'],
#       dtype='object')

# %%
df
# Out:
#            Category  Ticket Id         Due by Time            Group  Impact  \
# 0       CS-Vuln Mgt      37383 2025-04-03 14:00:00  InfraSec Celito  Medium
# 1     IS-Monitoring      37384 2025-04-11 08:00:12  InfraSec Celito     Low
# 2     IS-Monitoring      37385 2025-04-11 08:00:34  InfraSec Celito     Low
# 3           CS-SIEM      37386 2025-04-03 14:00:00  InfraSec Celito  Medium
# 4      CS-Email Sec      37389 2025-04-11 08:00:00  InfraSec Celito     Low
# ...             ...        ...                 ...              ...     ...
# 1197        CS-SIEM      39218 2025-07-10 17:00:00  InfraSec Celito     Low
# 1198  IS-Monitoring      39221 2025-07-11 09:42:36  InfraSec Celito     Low
# 1199  IS-Monitoring      39222 2025-07-11 12:50:00  InfraSec Celito     Low
# 1200  IS-Monitoring      39223 2025-07-11 13:25:45  InfraSec Celito     Low
# 1201  IS-Monitoring      39224 2025-07-11 15:11:00  InfraSec Celito     Low
#
#                Item Priority               Requester Email         Agent  \
# 0            Report   Medium     msanmiguel@celitotech.com  Akshay Velma
# 1            Report      Low     msanmiguel@celitotech.com  Akshay Velma
# 2            Report      Low     msanmiguel@celitotech.com  Akshay Velma
# 3            Benign   Medium    insight_noreply@rapid7.com  Akshay Velma
# 4            Benign      Low  mdr_notifications@rapid7.com  Akshay Velma
# ...             ...      ...                           ...           ...
# 1197         Benign      Low    insight_noreply@rapid7.com      No Agent
# 1198         Benign      Low    insight_noreply@rapid7.com  Akshay Velma
# 1199         Benign      Low   azure-noreply@microsoft.com  Akshay Velma
# 1200  True Positive      Low    kdaryabeygi@celitotech.com  Akshay Velma
# 1201         Report      Low    do-not-reply@jumpcloud.com  Akshay Velma
#
#       Status    Sub-Category  \
# 0     Closed  Scheduled Task
# 1     Closed  Scheduled Task
# 2     Closed  Scheduled Task
# 3     Closed        Incident
# 4     Closed        Incident
# ...      ...             ...
# 1197    Open             NaN
# 1198    Open             NaN
# 1199  Closed        Incident
# 1200    Open             NaN
# 1201  Closed        Incident
#
#                                                 Subject             Type  \
# 0                              Vulnerability Management  Service Request
# 1                               Email Forwarding Report  Service Request
# 2                                    Awareness Training  Service Request
# 3     New InsightIDR Investigation - Account nelson....         Incident
# 4     MDR Notification: Authentication Activity - Ce...         Incident
# ...                                                 ...              ...
# 1197  New InsightIDR Investigation - Helyx Data: Fai...         Incident
# 1198          Authorized user removed from your account         Incident
# 1199  Resolved:Sev3 Azure Monitor Alert Available Me...         Incident
# 1200  [Phish Alert] Celito Tech and Whiteswan Identi...         Incident
# 1201  JumpCloud Incident - Degraded System Insights ...         Incident
#
#                                             Close Notes         Closed Time  \
# 0     Report has been reviewed and remediation proje... 2025-05-13 06:50:01
# 1               Report has been generated and reviewed  2025-04-03 10:04:13
# 2              Awareness campaign is currently running  2025-04-29 08:08:17
# 3     Nothing suspicious found. Detailed investigati... 2025-04-02 05:30:19
# 4     Nothing suspicious found. Detailed investigati... 2025-04-02 05:32:26
# ...                                                 ...                 ...
# 1197                                                NaN                 NaT
# 1198                                                NaN                 NaT
# 1199  The memory usage on the virtual machine improv... 2025-07-02 07:53:22
# 1200                                                NaN                 NaT
# 1201              Jumpcloud is not being used in Jasper 2025-07-03 06:36:42
#
#             Created Time                           Department  \
# 0    2025-04-01 06:00:54  IT Infrastructure and Cybersecurity
# 1    2025-04-01 06:01:00  IT Infrastructure and Cybersecurity
# 2    2025-04-01 06:01:05  IT Infrastructure and Cybersecurity
# 3    2025-04-01 06:40:49  IT Infrastructure and Cybersecurity
# 4    2025-04-01 07:32:37  IT Infrastructure and Cybersecurity
# ...                  ...                                  ...
# 1197 2025-06-30 07:24:44                                  NaN
# 1198 2025-06-30 09:42:35                                  NaN
# 1199 2025-06-30 12:49:38  IT Infrastructure and Cybersecurity
# 1200 2025-06-30 13:25:44                                  NaN
# 1201 2025-06-30 15:10:46  IT Infrastructure and Cybersecurity
#
#                                             Description
# 0             Run reports, meet with team to prioritize
# 1                    Produce an email forwarding report
# 2     Review user list Review content to be sent Gen...
# 3     New InsightIDR investigation Account nelson.da...
# 4     This Message originated outside your organizat...
# ...                                                 ...
# 1197  New InsightIDR investigation Helyx Data: Faile...
# 1198   Basic Email Template This Message originated ...
# 1199  This Message originated outside your organizat...
# 1200  This Message originated outside your organizat...
# 1201  This Message originated outside your organizat...
#
# [1202 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Category', 'Ticket Id', 'Due by Time', 'Group', 'Impact', 'Item',
#        'Priority', 'Requester Email', 'Agent', 'Status', 'Sub-Category',
#        'Subject', 'Type', 'Close Notes', 'Closed Time', 'Created Time',
#        'Department', 'Description'],
#       dtype='object')

# %%
df.drop(['Group','Agent','Description','Department','Close Notes'],axis=1,inplace=True)

# %%
df
# Out:
#            Category  Ticket Id         Due by Time  Impact           Item  \
# 0       CS-Vuln Mgt      37383 2025-04-03 14:00:00  Medium         Report
# 1     IS-Monitoring      37384 2025-04-11 08:00:12     Low         Report
# 2     IS-Monitoring      37385 2025-04-11 08:00:34     Low         Report
# 3           CS-SIEM      37386 2025-04-03 14:00:00  Medium         Benign
# 4      CS-Email Sec      37389 2025-04-11 08:00:00     Low         Benign
# ...             ...        ...                 ...     ...            ...
# 1197        CS-SIEM      39218 2025-07-10 17:00:00     Low         Benign
# 1198  IS-Monitoring      39221 2025-07-11 09:42:36     Low         Benign
# 1199  IS-Monitoring      39222 2025-07-11 12:50:00     Low         Benign
# 1200  IS-Monitoring      39223 2025-07-11 13:25:45     Low  True Positive
# 1201  IS-Monitoring      39224 2025-07-11 15:11:00     Low         Report
#
#      Priority               Requester Email  Status    Sub-Category  \
# 0      Medium     msanmiguel@celitotech.com  Closed  Scheduled Task
# 1         Low     msanmiguel@celitotech.com  Closed  Scheduled Task
# 2         Low     msanmiguel@celitotech.com  Closed  Scheduled Task
# 3      Medium    insight_noreply@rapid7.com  Closed        Incident
# 4         Low  mdr_notifications@rapid7.com  Closed        Incident
# ...       ...                           ...     ...             ...
# 1197      Low    insight_noreply@rapid7.com    Open             NaN
# 1198      Low    insight_noreply@rapid7.com    Open             NaN
# 1199      Low   azure-noreply@microsoft.com  Closed        Incident
# 1200      Low    kdaryabeygi@celitotech.com    Open             NaN
# 1201      Low    do-not-reply@jumpcloud.com  Closed        Incident
#
#                                                 Subject             Type  \
# 0                              Vulnerability Management  Service Request
# 1                               Email Forwarding Report  Service Request
# 2                                    Awareness Training  Service Request
# 3     New InsightIDR Investigation - Account nelson....         Incident
# 4     MDR Notification: Authentication Activity - Ce...         Incident
# ...                                                 ...              ...
# 1197  New InsightIDR Investigation - Helyx Data: Fai...         Incident
# 1198          Authorized user removed from your account         Incident
# 1199  Resolved:Sev3 Azure Monitor Alert Available Me...         Incident
# 1200  [Phish Alert] Celito Tech and Whiteswan Identi...         Incident
# 1201  JumpCloud Incident - Degraded System Insights ...         Incident
#
#              Closed Time        Created Time
# 0    2025-05-13 06:50:01 2025-04-01 06:00:54
# 1    2025-04-03 10:04:13 2025-04-01 06:01:00
# 2    2025-04-29 08:08:17 2025-04-01 06:01:05
# 3    2025-04-02 05:30:19 2025-04-01 06:40:49
# 4    2025-04-02 05:32:26 2025-04-01 07:32:37
# ...                  ...                 ...
# 1197                 NaT 2025-06-30 07:24:44
# 1198                 NaT 2025-06-30 09:42:35
# 1199 2025-07-02 07:53:22 2025-06-30 12:49:38
# 1200                 NaT 2025-06-30 13:25:44
# 1201 2025-07-03 06:36:42 2025-06-30 15:10:46
#
# [1202 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Category             0
# Ticket Id            0
# Due by Time          0
# Impact               0
# Item                 0
# Priority             0
# Requester Email      0
# Status               0
# Sub-Category       497
# Subject              0
# Type                 0
# Closed Time         29
# Created Time         0
# dtype: int64

# %%
df['Sub-Category']=df['Sub-Category'].fillna("Incident")

# %%
df
# Out:
#            Category  Ticket Id         Due by Time  Impact           Item  \
# 0       CS-Vuln Mgt      37383 2025-04-03 14:00:00  Medium         Report
# 1     IS-Monitoring      37384 2025-04-11 08:00:12     Low         Report
# 2     IS-Monitoring      37385 2025-04-11 08:00:34     Low         Report
# 3           CS-SIEM      37386 2025-04-03 14:00:00  Medium         Benign
# 4      CS-Email Sec      37389 2025-04-11 08:00:00     Low         Benign
# ...             ...        ...                 ...     ...            ...
# 1197        CS-SIEM      39218 2025-07-10 17:00:00     Low         Benign
# 1198  IS-Monitoring      39221 2025-07-11 09:42:36     Low         Benign
# 1199  IS-Monitoring      39222 2025-07-11 12:50:00     Low         Benign
# 1200  IS-Monitoring      39223 2025-07-11 13:25:45     Low  True Positive
# 1201  IS-Monitoring      39224 2025-07-11 15:11:00     Low         Report
#
#      Priority               Requester Email  Status    Sub-Category  \
# 0      Medium     msanmiguel@celitotech.com  Closed  Scheduled Task
# 1         Low     msanmiguel@celitotech.com  Closed  Scheduled Task
# 2         Low     msanmiguel@celitotech.com  Closed  Scheduled Task
# 3      Medium    insight_noreply@rapid7.com  Closed        Incident
# 4         Low  mdr_notifications@rapid7.com  Closed        Incident
# ...       ...                           ...     ...             ...
# 1197      Low    insight_noreply@rapid7.com    Open        Incident
# 1198      Low    insight_noreply@rapid7.com    Open        Incident
# 1199      Low   azure-noreply@microsoft.com  Closed        Incident
# 1200      Low    kdaryabeygi@celitotech.com    Open        Incident
# 1201      Low    do-not-reply@jumpcloud.com  Closed        Incident
#
#                                                 Subject             Type  \
# 0                              Vulnerability Management  Service Request
# 1                               Email Forwarding Report  Service Request
# 2                                    Awareness Training  Service Request
# 3     New InsightIDR Investigation - Account nelson....         Incident
# 4     MDR Notification: Authentication Activity - Ce...         Incident
# ...                                                 ...              ...
# 1197  New InsightIDR Investigation - Helyx Data: Fai...         Incident
# 1198          Authorized user removed from your account         Incident
# 1199  Resolved:Sev3 Azure Monitor Alert Available Me...         Incident
# 1200  [Phish Alert] Celito Tech and Whiteswan Identi...         Incident
# 1201  JumpCloud Incident - Degraded System Insights ...         Incident
#
#              Closed Time        Created Time
# 0    2025-05-13 06:50:01 2025-04-01 06:00:54
# 1    2025-04-03 10:04:13 2025-04-01 06:01:00
# 2    2025-04-29 08:08:17 2025-04-01 06:01:05
# 3    2025-04-02 05:30:19 2025-04-01 06:40:49
# 4    2025-04-02 05:32:26 2025-04-01 07:32:37
# ...                  ...                 ...
# 1197                 NaT 2025-06-30 07:24:44
# 1198                 NaT 2025-06-30 09:42:35
# 1199 2025-07-02 07:53:22 2025-06-30 12:49:38
# 1200                 NaT 2025-06-30 13:25:44
# 1201 2025-07-03 06:36:42 2025-06-30 15:10:46
#
# [1202 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Category            0
# Ticket Id           0
# Due by Time         0
# Impact              0
# Item                0
# Priority            0
# Requester Email     0
# Status              0
# Sub-Category        0
# Subject             0
# Type                0
# Closed Time        29
# Created Time        0
# dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['CS-Vuln Mgt', 'IS-Monitoring', 'CS-SIEM', 'CS-Email Sec',
#        'Infrastructure', 'CS-PAM', 'Rapid7', 'IS-Backup Mgt', 'Druva',
#        'IS-Patch Mgt', 'CS-Health Check', 'CS-License Mgt', 'Mimecast',
#        'IS-Servers', 'Internet', 'CS-Cloud Sec', 'Zoom', 'CS-Data Sec'],
#       dtype=object)

# %%
df['Category'].nunique()
# Out:
# 18

# %%
df1=df

# %%
df.isnull().sum()
# Out:
# Category            0
# Ticket Id           0
# Due by Time         0
# Impact              0
# Item                0
# Priority            0
# Requester Email     0
# Status              0
# Sub-Category        0
# Subject             0
# Type                0
# Closed Time        29
# Created Time        0
# dtype: int64

# %%
df
# Out:
#            Category  Ticket Id         Due by Time  Impact           Item  \
# 0       CS-Vuln Mgt      37383 2025-04-03 14:00:00  Medium         Report
# 1     IS-Monitoring      37384 2025-04-11 08:00:12     Low         Report
# 2     IS-Monitoring      37385 2025-04-11 08:00:34     Low         Report
# 3           CS-SIEM      37386 2025-04-03 14:00:00  Medium         Benign
# 4      CS-Email Sec      37389 2025-04-11 08:00:00     Low         Benign
# ...             ...        ...                 ...     ...            ...
# 1197        CS-SIEM      39218 2025-07-10 17:00:00     Low         Benign
# 1198  IS-Monitoring      39221 2025-07-11 09:42:36     Low         Benign
# 1199  IS-Monitoring      39222 2025-07-11 12:50:00     Low         Benign
# 1200  IS-Monitoring      39223 2025-07-11 13:25:45     Low  True Positive
# 1201  IS-Monitoring      39224 2025-07-11 15:11:00     Low         Report
#
#      Priority               Requester Email  Status    Sub-Category  \
# 0      Medium     msanmiguel@celitotech.com  Closed  Scheduled Task
# 1         Low     msanmiguel@celitotech.com  Closed  Scheduled Task
# 2         Low     msanmiguel@celitotech.com  Closed  Scheduled Task
# 3      Medium    insight_noreply@rapid7.com  Closed        Incident
# 4         Low  mdr_notifications@rapid7.com  Closed        Incident
# ...       ...                           ...     ...             ...
# 1197      Low    insight_noreply@rapid7.com    Open        Incident
# 1198      Low    insight_noreply@rapid7.com    Open        Incident
# 1199      Low   azure-noreply@microsoft.com  Closed        Incident
# 1200      Low    kdaryabeygi@celitotech.com    Open        Incident
# 1201      Low    do-not-reply@jumpcloud.com  Closed        Incident
#
#                                                 Subject             Type  \
# 0                              Vulnerability Management  Service Request
# 1                               Email Forwarding Report  Service Request
# 2                                    Awareness Training  Service Request
# 3     New InsightIDR Investigation - Account nelson....         Incident
# 4     MDR Notification: Authentication Activity - Ce...         Incident
# ...                                                 ...              ...
# 1197  New InsightIDR Investigation - Helyx Data: Fai...         Incident
# 1198          Authorized user removed from your account         Incident
# 1199  Resolved:Sev3 Azure Monitor Alert Available Me...         Incident
# 1200  [Phish Alert] Celito Tech and Whiteswan Identi...         Incident
# 1201  JumpCloud Incident - Degraded System Insights ...         Incident
#
#              Closed Time        Created Time
# 0    2025-05-13 06:50:01 2025-04-01 06:00:54
# 1    2025-04-03 10:04:13 2025-04-01 06:01:00
# 2    2025-04-29 08:08:17 2025-04-01 06:01:05
# 3    2025-04-02 05:30:19 2025-04-01 06:40:49
# 4    2025-04-02 05:32:26 2025-04-01 07:32:37
# ...                  ...                 ...
# 1197                 NaT 2025-06-30 07:24:44
# 1198                 NaT 2025-06-30 09:42:35
# 1199 2025-07-02 07:53:22 2025-06-30 12:49:38
# 1200                 NaT 2025-06-30 13:25:44
# 1201 2025-07-03 06:36:42 2025-06-30 15:10:46
#
# [1202 rows x 13 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Category           0
# Ticket Id          0
# Due by Time        0
# Impact             0
# Item               0
# Priority           0
# Requester Email    0
# Status             0
# Sub-Category       0
# Subject            0
# Type               0
# Closed Time        0
# Created Time       0
# dtype: int64

# %%
df.shape
# Out:
# (1173, 13)

# %%
df['Resolution Time']=df['Closed Time']-df['Created Time']
df['Resolution Time'].mean()
# Out:
# Timedelta('3 days 12:33:01.749360613')

# %%
df['Lateness']=df['Closed Time']-df['Due by Time']
df['Lateness'].mean()
# Out:
# Timedelta('-7 days +11:57:26.655583973')

# %%
df
# Out:
#            Category  Ticket Id         Due by Time  Impact    Item Priority  \
# 0       CS-Vuln Mgt      37383 2025-04-03 14:00:00  Medium  Report   Medium
# 1     IS-Monitoring      37384 2025-04-11 08:00:12     Low  Report      Low
# 2     IS-Monitoring      37385 2025-04-11 08:00:34     Low  Report      Low
# 3           CS-SIEM      37386 2025-04-03 14:00:00  Medium  Benign   Medium
# 4      CS-Email Sec      37389 2025-04-11 08:00:00     Low  Benign      Low
# ...             ...        ...                 ...     ...     ...      ...
# 1193        CS-SIEM      39214 2025-07-11 08:00:22     Low  Benign      Low
# 1194          Druva      39215 2025-07-10 17:00:00     Low  Report      Low
# 1196   IS-Patch Mgt      39217 2025-07-10 17:00:00     Low  Report      Low
# 1199  IS-Monitoring      39222 2025-07-11 12:50:00     Low  Benign      Low
# 1201  IS-Monitoring      39224 2025-07-11 15:11:00     Low  Report      Low
#
#                    Requester Email  Status    Sub-Category  \
# 0        msanmiguel@celitotech.com  Closed  Scheduled Task
# 1        msanmiguel@celitotech.com  Closed  Scheduled Task
# 2        msanmiguel@celitotech.com  Closed  Scheduled Task
# 3       insight_noreply@rapid7.com  Closed        Incident
# 4     mdr_notifications@rapid7.com  Closed        Incident
# ...                            ...     ...             ...
# 1193    insight_noreply@rapid7.com  Closed        Incident
# 1194         cloud.admin@druva.com  Closed           Issue
# 1196     msanmiguel@celitotech.com  Closed  Scheduled Task
# 1199   azure-noreply@microsoft.com  Closed        Incident
# 1201    do-not-reply@jumpcloud.com  Closed        Incident
#
#                                                 Subject             Type  \
# 0                              Vulnerability Management  Service Request
# 1                               Email Forwarding Report  Service Request
# 2                                    Awareness Training  Service Request
# 3     New InsightIDR Investigation - Account nelson....         Incident
# 4     MDR Notification: Authentication Activity - Ce...         Incident
# ...                                                 ...              ...
# 1193  New InsightIDR Investigation - Helyx Data: Fai...         Incident
# 1194  Celito Technologies Inc : Weekly Alert Activit...         Incident
# 1196                                   Patch Management  Service Request
# 1199  Resolved:Sev3 Azure Monitor Alert Available Me...         Incident
# 1201  JumpCloud Incident - Degraded System Insights ...         Incident
#
#              Closed Time        Created Time  Resolution Time  \
# 0    2025-05-13 06:50:01 2025-04-01 06:00:54 42 days 00:49:07
# 1    2025-04-03 10:04:13 2025-04-01 06:01:00  2 days 04:03:13
# 2    2025-04-29 08:08:17 2025-04-01 06:01:05 28 days 02:07:12
# 3    2025-04-02 05:30:19 2025-04-01 06:40:49  0 days 22:49:30
# 4    2025-04-02 05:32:26 2025-04-01 07:32:37  0 days 21:59:49
# ...                  ...                 ...              ...
# 1193 2025-07-07 08:50:22 2025-06-29 23:58:44  7 days 08:51:38
# 1194 2025-07-11 09:43:41 2025-06-30 04:28:54 11 days 05:14:47
# 1196 2025-07-11 10:01:07 2025-06-30 06:00:11 11 days 04:00:56
# 1199 2025-07-02 07:53:22 2025-06-30 12:49:38  1 days 19:03:44
# 1201 2025-07-03 06:36:42 2025-06-30 15:10:46  2 days 15:25:56
#
#                Lateness
# 0      39 days 16:50:01
# 1     -8 days +02:04:01
# 2      18 days 00:07:43
# 3     -2 days +15:30:19
# 4    -10 days +21:32:26
# ...                 ...
# 1193  -4 days +00:50:00
# 1194    0 days 16:43:41
# 1196    0 days 17:01:07
# 1199 -10 days +19:03:22
# 1201  -9 days +15:25:42
#
# [1173 rows x 15 columns]

# %%
df['Resolution Time'].mean()
# Out:
# Timedelta('3 days 12:33:01.749360613')

# %%
df['Lateness'].mean()
# Out:
# Timedelta('-7 days +11:57:26.655583973')

# %%
f_df=df['Category'].value_counts().reset_index()

# %%
f_df
# Out:
#            Category  count
# 0      CS-Cloud Sec    414
# 1           CS-SIEM    402
# 2     IS-Monitoring    177
# 3      CS-Email Sec     74
# 4     IS-Backup Mgt     34
# 5   CS-Health Check     34
# 6      IS-Patch Mgt     13
# 7             Druva      7
# 8       CS-Vuln Mgt      6
# 9            CS-PAM      4
# 10   CS-License Mgt      3
# 11       IS-Servers      2
# 12      CS-Data Sec      2
# 13   Infrastructure      1

# %%
f_df.columns=['Category','Freq']

# %%
f_df
# Out:
#            Category  Freq
# 0      CS-Cloud Sec   414
# 1           CS-SIEM   402
# 2     IS-Monitoring   177
# 3      CS-Email Sec    74
# 4     IS-Backup Mgt    34
# 5   CS-Health Check    34
# 6      IS-Patch Mgt    13
# 7             Druva     7
# 8       CS-Vuln Mgt     6
# 9            CS-PAM     4
# 10   CS-License Mgt     3
# 11       IS-Servers     2
# 12      CS-Data Sec     2
# 13   Infrastructure     1

# %%
sns.barplot(data=f_df,x='Category',y='Freq')
plt.figure(figsize=(8,5))

# %%
type(f_df)
f_df
# Out:
#            Category  Freq
# 0      CS-Cloud Sec   414
# 1           CS-SIEM   402
# 2     IS-Monitoring   177
# 3      CS-Email Sec    74
# 4     IS-Backup Mgt    34
# 5   CS-Health Check    34
# 6      IS-Patch Mgt    13
# 7             Druva     7
# 8       CS-Vuln Mgt     6
# 9            CS-PAM     4
# 10   CS-License Mgt     3
# 11       IS-Servers     2
# 12      CS-Data Sec     2
# 13   Infrastructure     1

# %%
# sns.lineplot(data=df,x='Category',y='Created Time',hue='Item')

trend_df=df.loc[:,['Item','Created Time']]
trend_df['Created Time']=trend_df['Created Time'].dt.date
trend_df=trend_df.groupby(['Item','Created Time']).size().reset_index(name='count')
plt.figure(figsize=(10,3))
sns.lineplot(data=trend_df,y='count',x='Created Time',hue='Item',palette=[
    "#9467BD",
    "#1F77B4",
    "#FF7F0E",
    "#17BECF",  
    "#2CA02C",
])
trend_df
# Out:
#               Item Created Time  count
# 0           Benign   2025-04-01      7
# 1           Benign   2025-04-02      5
# 2           Benign   2025-04-03      9
# 3           Benign   2025-04-04      3
# 4           Benign   2025-04-06      1
# ..             ...          ...    ...
# 211  True Positive   2025-06-23      2
# 212  True Positive   2025-06-24      2
# 213  True Positive   2025-06-27      2
# 214  True Positive   2025-06-29      2
# 215       Wireless   2025-04-01      1
#
# [216 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
# sns.barplot(data=trend_df,x='Created Time',y='count')
# trend_df.head(1200)
# False Positive	2025-05-15	396 max one.. anomaly
# trend_df.drop()
trend_df['Created Time'] = pd.to_datetime(trend_df['Created Time'])
target_date = pd.to_datetime('2025-05-15').date()
trend_df = trend_df[trend_df['Created Time'].dt.date !=target_date]
# trend_df
sns.lineplot(data=trend_df,x='Created Time',y='count',hue='Item',palette=[
    "#1F77B4",  # medium blue
    "#2CA02C",  # teal-green
    "#9467BD",  # soft purple
    "#17BECF",  # cyan
    "#FF7F0E"   # orange for strong contrast
])
trend_df
# Out:
#               Item Created Time  count
# 0           Benign   2025-04-01      7
# 1           Benign   2025-04-02      5
# 2           Benign   2025-04-03      9
# 3           Benign   2025-04-04      3
# 4           Benign   2025-04-06      1
# ..             ...          ...    ...
# 211  True Positive   2025-06-23      2
# 212  True Positive   2025-06-24      2
# 213  True Positive   2025-06-27      2
# 214  True Positive   2025-06-29      2
# 215       Wireless   2025-04-01      1
#
# [213 rows x 3 columns]

# %%
trend_df['count'].mean()
# Out:
# np.float64(3.568075117370892)

# %%
i_df=df[(df['Item']=='False Positive')&(df['Category']=='CS-Cloud Sec')]

# %%
i_df
# Out:
#          Category  Ticket Id         Due by Time Impact            Item  \
# 156  CS-Cloud Sec      37622 2025-04-14 12:00:00   High  False Positive
# 159  CS-Cloud Sec      37628 2025-04-14 12:00:00   High  False Positive
# 162  CS-Cloud Sec      37635 2025-04-14 14:42:10   High  False Positive
# 163  CS-Cloud Sec      37636 2025-04-14 15:01:13   High  False Positive
# 173  CS-Cloud Sec      37654 2025-04-15 12:00:05   High  False Positive
# ..            ...        ...                 ...    ...             ...
# 163    0 days 17:05:51  2025-04-14
# 173  -1 days +20:06:00  2025-04-15
# ..                 ...         ...
# 842 -12 days +15:56:22  2025-05-15
# 843 -12 days +15:54:27  2025-05-15
# 928 -12 days +13:44:37  2025-05-28
# 948 -12 days +03:49:00  2025-05-30
# 949 -12 days +03:41:00  2025-05-30
#
# [414 rows x 16 columns]

# %%
t_df=((w_df.groupby('date'))['Item'].count()).reset_index()

# %%
t_df.columns=['date','freq']

# %%
t_df
# Out:
#           date  freq
# 0   2025-04-14     4
# 1   2025-04-15     2
# 2   2025-04-17     2
# 3   2025-04-21     1
# 4   2025-04-22     1
# 5   2025-04-24     1
# 6   2025-05-06     1
# 7   2025-05-14     6
# 8   2025-05-15   393
# 9   2025-05-28     1
# 10  2025-05-30     2

# %%
sns.lineplot(data=t_df,x='date',y='freq')
plt.figure(figsize=(12,12))

# %%
# true positive trend
# w_df['date']=w_df['Created Time'].dt.date
tpt_df=df.loc[:,['Item','Created Time']]
tpt_df['Created Time']=tpt_df['Created Time'].dt.date
tpt_df
ftpt_df=tpt_df.groupby(['Item','Created Time'])['Item'].count().reset_index(name='count')
plt.figure(figsize=(9,4))
sns.lineplot(x='Created Time',y='count',data=ftpt_df,hue='Item',palette=[
    "#A7C7E7",  # pastel blue
    "#5DADEC",  # sky blue
    "#187BCD",  # royal blue
    "#0B4F6C",  # deep teal-blue
    "#001F54"   # navy blue
])
ftpt_df
ffdf=ftpt_df[ftpt_df['Item']=='True Positive']
# sns.lineplot(x='Created Time',y='count',data=ffdf,hue='Item')
ftpt_df.to_excel('scatterplot.xlsx')
# ffdf

# %%
#category wise count
plt.figure(figsize=(20,9))
sns.barplot(x='Category',y='Freq',data=f_df)
f_df
# Out:
#            Category  Freq
# 0      CS-Cloud Sec   414
# 1           CS-SIEM   402
# 2     IS-Monitoring   177
# 3      CS-Email Sec    74
# 4     IS-Backup Mgt    34
# 5   CS-Health Check    34
# 6      IS-Patch Mgt    13
# 7             Druva     7
# 8       CS-Vuln Mgt     6
# 9            CS-PAM     4
# 10   CS-License Mgt     3
# 11       IS-Servers     2
# 12      CS-Data Sec     2
# 13   Infrastructure     1

# %%
ff_df=df.loc[:,['Item']]
ff_df=ff_df.groupby('Item')['Item'].count().reset_index(name='freq')
ff_df
# plt.pie(ff_df['freq'], labels=ff_df['Item'], autopct='%1.1f%%', startangle=90,colors=["#A8DADC", "#457B9D", "#FCD581", "#F4A261", "#FFE66D"])
# Out:
#              Item  freq
# 0          Benign   348
# 1  False Positive   487
# 2          Report   116
# 3   True Positive   221
# 4        Wireless     1

# %%
time_df=df.loc[:,['Item','Created Time']]
time_df['Created Time']=time_df['Created Time'].dt.month
time_df=time_df.groupby('Created Time')['Created Time'].count().reset_index(name='Freq')
time_df['RelFreq'] = time_df['Freq'] / time_df['Freq'].sum()
time_df
sns.barplot(data=time_df,x='Created Time',y='Freq')
# Out:
# <Axes: xlabel='Created Time', ylabel='Freq'>

# %%
# sns.lineplot(data=df,x='Category',y='Created Time',hue='Item')

trend_df1=df.loc[:,['Item','Created Time']]
trend_df1['Created Time'] = pd.to_datetime(trend_df1['Created Time'])
trend_df1 = trend_df1[trend_df1['Created Time'].dt.date !=target_date]
trend_df1['Created Time']=trend_df1['Created Time'].dt.month
trend_df1=trend_df1.groupby(['Created Time']).size().reset_index(name='count')
plt.figure(figsize=(20,3))
# sns.lineplot(data=trend_df1,y='count',x='Created Time',hue='Item')
trend_df1['RelFreq'] = trend_df1['count'] / trend_df1['count'].sum()
trend_df1
# Out:
#    Created Time  count   RelFreq
# 0             4    281  0.369737
# 1             5    252  0.331579
# 2             6    227  0.298684

# %% [markdown]
# reg_time_df=time_df[time_df['Created Time']!='2025-06-30']
# reg_time_df

# %%
sns.scatterplot(data=trend_df,x='Created Time',y='count')
# Out:
# <Axes: xlabel='Created Time', ylabel='count'>

# %%
anomaly=df.loc[:,['Item','Created Time']]
anomaly['Created Time']=anomaly['Created Time'].dt.date
anomaly
anomaly=anomaly.groupby(['Created Time']).size().reset_index(name='count')
anomaly
plt.figure(figsize=(9,3))
sns.scatterplot(data=anomaly,x='Created Time',y='count')
anomaly['Created Time'] = pd.to_datetime(anomaly['Created Time'])
anomaly
anomaly.to_excel("scatterplot.xlsx", sheet_name="Scatterplot", index=False)

# %%
anomaly=df.loc[:,['Item','Created Time']]
anomaly['Created Time']=anomaly['Created Time'].dt.date
anomaly=anomaly.groupby(['Item']).size().reset_index(name='count_of_items')
anomaly
# Out:
#              Item  count_of_items
# 0          Benign             348
# 1  False Positive             487
# 2          Report             116
# 3   True Positive             221
# 4        Wireless               1

# %%
critical=df[(df['Priority']=='High') | (df['Priority']=='Urgent')]
critical
# Out:
#            Category  Ticket Id         Due by Time Impact            Item  \
# 16          CS-SIEM      37403 2025-04-01 12:26:47   High  False Positive
# 46          CS-SIEM      37440 2025-04-02 12:00:00   High  False Positive
# 51          CS-SIEM      37448 2025-04-02 12:43:31   High          Benign
# 55          CS-SIEM      37454 2025-04-03 08:47:21   High  False Positive
# 72          CS-SIEM      37478 2025-04-04 10:21:00   High  False Positive
# 78          CS-SIEM      37487 2025-04-04 12:27:55   High  False Positive
# 79          CS-SIEM      37488 2025-04-04 12:51:33   High  False Positive
# 83          CS-SIEM      37499 2025-04-07 12:00:00   High  False Positive
# 85          CS-SIEM      37501 2025-04-07 12:00:00   High  False Positive
# 112         CS-SIEM      37534 2025-04-08 12:00:00   High  False Positive
# 136         CS-SIEM      37585 2025-04-10 13:42:07   High  False Positive
# 156    CS-Cloud Sec      37622 2025-04-14 12:00:00   High  False Positive
# 159    CS-Cloud Sec      37628 2025-04-14 12:00:00   High  False Positive
# 162    CS-Cloud Sec      37635 2025-04-14 14:42:10   High  False Positive
# 163    CS-Cloud Sec      37636 2025-04-14 15:01:13   High  False Positive
# 173    CS-Cloud Sec      37654 2025-04-15 12:00:05   High  False Positive
# 185    CS-Cloud Sec      37677 2025-04-17 11:00:11    Low  False Positive
# 186         CS-SIEM      37682 2025-04-16 12:45:24   High  False Positive
# 163   High-severity alert: A potentially malicious U...  Incident
# 173   High-severity alert: A potentially malicious U...  Incident
# 185   High-severity alert: A potentially malicious U...  Incident
# 186   New InsightIDR Investigation - Remote file exe...  Incident
# 187   New InsightIDR Investigation - Remote file exe...  Incident
# 188   New InsightIDR Investigation - Admin Privilege...  Incident
# 189   New InsightIDR Investigation - Member Added to...  Incident
# 195   High-severity alert: A potentially malicious U...  Incident
# 196   High-severity alert: A potentially malicious U...  Incident
# 209   New InsightIDR Investigation - Remote file exe...  Incident
# 220   High-severity alert: A potentially malicious U...  Incident
# 236   High-severity alert: A potentially malicious U...  Incident
# 247   New InsightIDR Investigation - Member Added to...  Incident
# 251   High-severity alert: A potentially malicious U...  Incident
# 283   New InsightIDR Investigation - Member Added to...  Incident
# 284   New InsightIDR Investigation - Admin Privilege...  Incident
# 304   New InsightIDR Investigation - Admin Privilege...  Incident
# 324        High-severity alert: BizOps File Data in Use  Incident
# 326        High-severity alert: BizOps File Data in Use  Incident
# 327        High-severity alert: BizOps File Data in Use  Incident
# 328        High-severity alert: BizOps File Data in Use  Incident
# 329        High-severity alert: BizOps File Data in Use  Incident
# 334        High-severity alert: BizOps File Data in Use  Incident
# 335        High-severity alert: BizOps File Data in Use  Incident
# 340        High-severity alert: BizOps File Data in Use  Incident
# 344           High-severity alert: BizOps Data Modified  Incident
# 389   New InsightIDR Investigation - Helyx Data Logi...  Incident
# 391   New InsightIDR Investigation - Helyx Data Logi...  Incident
# 392   New InsightIDR Investigation - Helyx Data Logi...  Incident
# 393   New InsightIDR Investigation - Helyx Data Logi...  Incident
# 439   New InsightIDR Investigation - Helyx Data: Fai...  Incident
# 679   New InsightIDR Investigation - Helyx Data: Fai...  Incident
# 845   New InsightIDR Investigation - Helyx Data: Fai...  Incident
# 846   New InsightIDR Investigation - Helyx Data: Fai...  Incident
# 890   New InsightIDR Investigation - Admin Privilege...  Incident
# 911   New InsightIDR Investigation - Helyx Data: Fai...  Incident
# 916   New InsightIDR Investigation - Helyx Data: Fai...  Incident
# 936   New InsightIDR Investigation - Helyx: New User...  Incident
# 951   New InsightIDR Investigation - Helyx Data – Cr...  Incident
# 985   New InsightIDR Investigation - Helyx Data: Fai...  Incident
# 1136  New InsightIDR Investigation - Helyx Data: Rol...  Incident
# 1183  New InsightIDR Investigation - Helyx Data: Fai...  Incident
#
#              Closed Time        Created Time Resolution Time          Lateness
# 16   2025-04-02 05:19:58 2025-04-01 08:26:47 0 days 20:53:11   0 days 16:53:11
# 46   2025-04-02 05:18:01 2025-04-01 21:07:41 0 days 08:10:20 -1 days +17:18:01
# 51   2025-04-04 07:11:41 2025-04-02 08:43:31 1 days 22:28:10   1 days 18:28:10
# 55   2025-04-03 10:05:58 2025-04-02 13:47:21 0 days 20:18:37   0 days 01:18:37
# 72   2025-04-04 05:21:12 2025-04-03 15:20:42 0 days 14:00:30 -1 days +19:00:12
# 78   2025-04-04 10:03:55 2025-04-04 08:27:07 0 days 01:36:48 -1 days +21:36:00
# 79   2025-04-04 10:04:28 2025-04-04 08:51:26 0 days 01:13:02 -1 days +21:12:55
# ...             ...        ...                 ...     ...     ...      ...
# 1193        CS-SIEM      39214 2025-07-11 08:00:22     Low  Benign      Low
# 1194          Druva      39215 2025-07-10 17:00:00     Low  Report      Low
# 1196   IS-Patch Mgt      39217 2025-07-10 17:00:00     Low  Report      Low
# 1199  IS-Monitoring      39222 2025-07-11 12:50:00     Low  Benign      Low
# 1201  IS-Monitoring      39224 2025-07-11 15:11:00     Low  Report      Low
#
#                    Requester Email  Status    Sub-Category  \
# 0        msanmiguel@celitotech.com  Closed  Scheduled Task
# 1        msanmiguel@celitotech.com  Closed  Scheduled Task
# 2        msanmiguel@celitotech.com  Closed  Scheduled Task
# 3       insight_noreply@rapid7.com  Closed        Incident
# 4     mdr_notifications@rapid7.com  Closed        Incident
# ...                            ...     ...             ...
# 1193    insight_noreply@rapid7.com  Closed        Incident
# 1194         cloud.admin@druva.com  Closed           Issue
# 1196     msanmiguel@celitotech.com  Closed  Scheduled Task
# 1199   azure-noreply@microsoft.com  Closed        Incident
# 1201    do-not-reply@jumpcloud.com  Closed        Incident
#
#                                                 Subject             Type  \
# 0                              Vulnerability Management  Service Request
# 1                               Email Forwarding Report  Service Request
# 2                                    Awareness Training  Service Request
# 3     New InsightIDR Investigation - Account nelson....         Incident
# 4     MDR Notification: Authentication Activity - Ce...         Incident
# ...                                                 ...              ...
# 1193  New InsightIDR Investigation - Helyx Data: Fai...         Incident
# 1194  Celito Technologies Inc : Weekly Alert Activit...         Incident
# 1196                                   Patch Management  Service Request
# 1199  Resolved:Sev3 Azure Monitor Alert Available Me...         Incident
# 1201  JumpCloud Incident - Degraded System Insights ...         Incident
#
#              Closed Time        Created Time  Resolution Time  \
# 0    2025-05-13 06:50:01 2025-04-01 06:00:54 42 days 00:49:07
# 1    2025-04-03 10:04:13 2025-04-01 06:01:00  2 days 04:03:13
# 2    2025-04-29 08:08:17 2025-04-01 06:01:05 28 days 02:07:12
# 3    2025-04-02 05:30:19 2025-04-01 06:40:49  0 days 22:49:30
# 4    2025-04-02 05:32:26 2025-04-01 07:32:37  0 days 21:59:49
# ...                  ...                 ...              ...
# 1193 2025-07-07 08:50:22 2025-06-29 23:58:44  7 days 08:51:38
# 1194 2025-07-11 09:43:41 2025-06-30 04:28:54 11 days 05:14:47
# 1196 2025-07-11 10:01:07 2025-06-30 06:00:11 11 days 04:00:56
# 1199 2025-07-02 07:53:22 2025-06-30 12:49:38  1 days 19:03:44
# 1201 2025-07-03 06:36:42 2025-06-30 15:10:46  2 days 15:25:56
#
#                Lateness
# 0      39 days 16:50:01
# 1     -8 days +02:04:01
# 2      18 days 00:07:43
# 3     -2 days +15:30:19
# 4    -10 days +21:32:26
# ...                 ...
# 1193  -4 days +00:50:00
# 1194    0 days 16:43:41
# 1196    0 days 17:01:07
# 1199 -10 days +19:03:22
# 1201  -9 days +15:25:42
#
# [1173 rows x 15 columns]

# %%
df.columns
df['Resolution Time'].dtype
# Out:
# dtype('<m8[ns]')

# %%
df['Resolution Time']=df['Resolution Time'].dt.total_seconds()/3600

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
tdf=df.loc[:,['Impact','Priority','Status','Type','Item','Category','Sub-Category','Resolution Time']]
tdf
# Out:
#       Impact Priority  Status             Type    Item       Category  \
# 0     Medium   Medium  Closed  Service Request  Report    CS-Vuln Mgt
# 1        Low      Low  Closed  Service Request  Report  IS-Monitoring
# 2        Low      Low  Closed  Service Request  Report  IS-Monitoring
# 3     Medium   Medium  Closed         Incident  Benign        CS-SIEM
# 4        Low      Low  Closed         Incident  Benign   CS-Email Sec
# ...      ...      ...     ...              ...     ...            ...
# 1193     Low      Low  Closed         Incident  Benign        CS-SIEM
# 1194     Low      Low  Closed         Incident  Report          Druva
# 1196     Low      Low  Closed  Service Request  Report   IS-Patch Mgt
# 1199     Low      Low  Closed         Incident  Benign  IS-Monitoring
# 1201     Low      Low  Closed         Incident  Report  IS-Monitoring
#
#         Sub-Category  Resolution Time
# 0     Scheduled Task      1008.818611
# 1     Scheduled Task        52.053611
# 2     Scheduled Task       674.120000
# 3           Incident        22.825000
# 4           Incident        21.996944
# ...              ...              ...
# 1193        Incident       176.860556
# 1194           Issue       269.246389
# 1196  Scheduled Task       268.015556
# 1199        Incident        43.062222
# 1201        Incident        63.432222
#
# [1173 rows x 8 columns]

# %%
# tdf['Impact'].value_counts()
# tdf['Priority'].value_counts()
# tdf['Status'].value_counts()
# tdf['Type'].value_counts()
tdf['Item'].value_counts()
print(df['Item'].value_counts())
# Out:
# Item
# False Positive    487
# Benign            348
# True Positive     221
# Report            116
# Wireless            1
# Name: count, dtype: int64

# %%
tdf['Impact']=tdf['Impact'].map({"Low":-1,"Medium":0,"High":1})
tdf['Priority']=tdf['Priority'].map({"Low":-1,"Medium":0,"High":1,"Urgent":2})
tdf['Status']=tdf['Status'].map({"Closed":1})
tdf['Type']=tdf['Type'].map({"Service Request":1,"Incident":0})
tdf['Item']=tdf['Item'].map({"False Positive":-1,"Benign":0,"True Positive":1,"Report":2,"Wireless":3})

# %%
tdf
# Out:
#       Impact  Priority  Status  Type  Item       Category    Sub-Category  \
# 0          0         0       1     1     2    CS-Vuln Mgt  Scheduled Task
# 1         -1        -1       1     1     2  IS-Monitoring  Scheduled Task
# 2         -1        -1       1     1     2  IS-Monitoring  Scheduled Task
# 3          0         0       1     0     0        CS-SIEM        Incident
# 4         -1        -1       1     0     0   CS-Email Sec        Incident
# ...      ...       ...     ...   ...   ...            ...             ...
# 1193      -1        -1       1     0     0        CS-SIEM        Incident
# 1194      -1        -1       1     0     2          Druva           Issue
# 1196      -1        -1       1     1     2   IS-Patch Mgt  Scheduled Task
# 1199      -1        -1       1     0     0  IS-Monitoring        Incident
# 1201      -1        -1       1     0     2  IS-Monitoring        Incident
#
#       Resolution Time
# 0         1008.818611
# 1           52.053611
# 2          674.120000
# 3           22.825000
# 4           21.996944
# ...               ...
# 1193       176.860556
# 1194       269.246389
# 1196       268.015556
# 1199        43.062222
# 1201        63.432222
#
# [1173 rows x 8 columns]

# %%
tdf['Category']=le.fit_transform(tdf['Category'])
print(le.classes_)
mapping = dict(zip(le.classes_, le.transform(le.classes_)))
mapping
# Out:
# ['CS-Cloud Sec' 'CS-Data Sec' 'CS-Email Sec' 'CS-Health Check'
#  'CS-License Mgt' 'CS-PAM' 'CS-SIEM' 'CS-Vuln Mgt' 'Druva' 'IS-Backup Mgt'
#  'IS-Monitoring' 'IS-Patch Mgt' 'IS-Servers' 'Infrastructure']
# {'CS-Cloud Sec': np.int64(0),
#  'CS-Data Sec': np.int64(1),
#  'CS-Email Sec': np.int64(2),
#  'CS-Health Check': np.int64(3),
#  'CS-License Mgt': np.int64(4),
#  'CS-PAM': np.int64(5),
#  'CS-SIEM': np.int64(6),
#  'CS-Vuln Mgt': np.int64(7),
#  'Druva': np.int64(8),
#  'IS-Backup Mgt': np.int64(9),
#  'IS-Monitoring': np.int64(10),
#  'IS-Patch Mgt': np.int64(11),
#  'IS-Servers': np.int64(12),
#  'Infrastructure': np.int64(13)}

# %%
tdf['Sub-Category']=le.fit_transform(tdf['Sub-Category'])
mapping = dict(zip(le.classes_, le.transform(le.classes_)))
mapping
# Out:
# {'Adhoc Task': np.int64(0),
#  'Incident': np.int64(1),
#  'Issue': np.int64(2),
#  'Reports': np.int64(3),
#  'Rrequest': np.int64(4),
#  'Scheduled Task': np.int64(5),
#  'Service Request': np.int64(6)}

# %%
X=tdf[['Impact','Priority','Status','Type','Category','Sub-Category','Resolution Time']]
y=tdf['Item']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.3)
dtc=DecisionTreeClassifier()
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=dtc.predict([[0,0,1,0,6,1,215.4333]])
y_pred=dtc.predict(X_test)
pred
# Out:
# c:\Users\archi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.metrics import accuracy_score, classification_report
print(accuracy_score(y_test, y_pred)*100)
print(classification_report(y_test, y_pred))
# Out:
# 78.97727272727273
#               precision    recall  f1-score   support
#
#           -1       0.91      0.94      0.93       153
#            0       0.67      0.62      0.65        98
#            1       0.71      0.68      0.70        73
#            2       0.70      0.82      0.75        28
#
#     accuracy                           0.79       352
#    macro avg       0.75      0.77      0.76       352
# weighted avg       0.79      0.79      0.79       352

# %%
tdf
# Out:
#       Impact  Priority  Status  Type  Item  Category  Sub-Category  \
# 0          0         0       1     1     2         7             5
# 1         -1        -1       1     1     2        10             5
# 2         -1        -1       1     1     2        10             5
# 3          0         0       1     0     0         6             1
# 4         -1        -1       1     0     0         2             1
# ...      ...       ...     ...   ...   ...       ...           ...
# 1193      -1        -1       1     0     0         6             1
# 1194      -1        -1       1     0     2         8             2
# 1196      -1        -1       1     1     2        11             5
# 1199      -1        -1       1     0     0        10             1
# 1201      -1        -1       1     0     2        10             1
#
#       Resolution Time
# 0         1008.818611
# 1           52.053611
# 2          674.120000
# 3           22.825000
# 4           21.996944
# ...               ...
# 1193       176.860556
# 1194       269.246389
# 1196       268.015556
# 1199        43.062222
# 1201        63.432222
#
# [1173 rows x 8 columns]

# %%
# implmentation of randon forest classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
RF=RandomForestClassifier( n_estimators=100,random_state=42)
RF.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=RF.predict(X_test)

# %%
acc=accuracy_score(y_test,y_pred)
print(acc*100)
# Out:
# 79.82954545454545
